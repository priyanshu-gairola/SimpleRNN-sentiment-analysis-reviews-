# %%
# Step 1: Import Libraries and Load the Model
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import load_model
# Out:
# WARNING:tensorflow:From c:\Users\priyanshu gairola\GEn_ai Project\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load the IMDB dataset word index
word_index = imdb.get_word_index()
reverse_word_index = {value: key for key, value in word_index.items()}

# %%
# Load the pre-trained model with ReLU activation
model = load_model('simple_rnn_imdb.h5')
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\priyanshu gairola\GEn_ai Project\venv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 500, 128)          1280000
#
#  simple_rnn (SimpleRNN)      (None, 128)               32896
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 1313025 (5.01 MB)
# Trainable params: 1313025 (5.01 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.get_weights()
#The model.get_weights() function in Keras (or TensorFlow) retrieves the weights (parameters) of a model after training.
# Out:
# [array([[ 0.02417521, -0.01214779,  0.0436563 , ..., -0.02590955,
#          -0.06678928, -0.01669436],
#         [ 0.01064645,  0.01767204,  0.00504535, ..., -0.00185726,
#          -0.00866953, -0.02825888],
#         [-0.04749974,  0.03733118,  0.07924488, ...,  0.00656521,
#          -0.09761796, -0.02829815],
#         ...,
#         [-0.05374417, -0.00997399, -0.03443596, ..., -0.07178238,
#           0.03387086,  0.05715676],
#         [-0.01767183,  0.04048077,  0.12352377, ...,  0.08277773,
#          -0.07297777, -0.04842355],
#         [ 0.1541105 , -0.06386931, -0.10344601, ..., -0.04971826,
#           0.09554055, -0.05577184]], dtype=float32),
#  array([[ 0.13050601,  0.11970857,  0.05876866, ..., -0.05103725,
#           0.05015964,  0.02568622],
#         [ 0.1177945 , -0.06442746,  0.05763723, ..., -0.01121162,
#          -0.11948879, -0.08051602],
#         [-0.03237241,  0.10152971,  0.1843853 , ..., -0.11759403,
#          -0.19366355, -0.10627118],
# ...

# %%
# Step 2: Helper Functions
# Function to decode reviews
def decode_review(encoded_review):
    return ' '.join([reverse_word_index.get(i - 3, '?') for i in encoded_review])

# Function to preprocess user input
def preprocess_text(text):
    words = text.lower().split()
    encoded_review = [word_index.get(word, 2) + 3 for word in words]
    # # For each word in 'words':
    # - `word_index.get(word, 2)` looks up its integer encoding in 'word_index'.
    #   If the word isn't found, it returns 2 (often reserved for 'unknown' tokens).
    # - Adding 3 adjusts the index to match encoding conventions (accounting for reserved initial indices).
    # - This produces 'encoded_review', a list of integers corresponding to each word in the review.
    
    padded_review = sequence.pad_sequences([encoded_review], maxlen=500)
    return padded_review

# %%
### Prediction  function

def predict_sentiment(review):
    preprocessed_input=preprocess_text(review)

    prediction=model.predict(preprocessed_input)

    sentiment = 'Positive' if prediction[0][0] > 0.5 else 'Negative'
    
    return sentiment, prediction[0][0]

# %%
# Step 4: User Input and Prediction
# Example review for prediction
example_review = "This movie was fantastic! The acting was great and the plot was thrilling."

sentiment,score=predict_sentiment(example_review)

print(f'Review: {example_review}')
print(f'Sentiment: {sentiment}')
print(f'Prediction Score: {score}')
# Out:
# 1/1 [==============================] - 1s 609ms/step
# Review: This movie was fantastic! The acting was great and the plot was thrilling.
# Sentiment: Negative
# Prediction Score: 0.2725297808647156

# %%
one_more_example="This movie was not good as it was expected . Could be much better"

sentiment,score=predict_sentiment(one_more_example)

print(f'Review: {one_more_example}')
print(f'Sentiment: {sentiment}')
print(f'Prediction Score: {score}')
# Out:
# 1/1 [==============================] - 0s 71ms/step
# Review: This movie was not good as it was expected . Could be much better
# Sentiment: Negative
# Prediction Score: 0.3923105299472809
